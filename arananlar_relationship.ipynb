# %%
from bs4 import BeautifulSoup
import requests
from requests_html import HTMLSession
from PIL import Image
import io
from io import BytesIO
import json
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy_utils import database_exists, create_database
import psycopg2
from sqlalchemy.dialects import postgresql
from sqlalchemy import Table, Column, String, MetaData,Integer,Date,Numeric,Boolean,ForeignKey,TEXT,LargeBinary
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship,aliased
from sqlalchemy import insert
from sqlalchemy.dialects.postgresql import insert
from sqlalchemy import create_engine, MetaData, Table, insert
from zope.sqlalchemy import mark_changed
import pandas as pd
import numpy as np

# %%
with open('response_2.json',"r+",encoding="'utf-8-sig") as f:
   
    data = (json.load(f,strict=False))
tamliste=list()
imglist=list()

tehlike=["kirmizi","mavi","yesil","turuncu","gri"]
for a in tehlike:
    for i in data[a]:
        
        
            #if(i['GorselURL']!="null" and i['Adi']!="Abdulgafur"):
                for c in i['GorselURL'] or []:
                    response = c
                    imglist.append(response)
           

                list2=[i['Adi'],i['Soyadi'],i['DogumYeri'],i['DogumTarihi'],i['TOrgutAdi'],i['TKategoriAdi']]
                list2=list2+imglist
                #print(list2)
                list2=map(str,list2)
                list2=list(list2)
            
                tamliste.append(list2)
                list2=[]
                imglist=[]
print(tamliste)
# Out:
# [['Yunus', 'DURMAZ', 'GAZIANTEP', '1986', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/133/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/133/FotoOrj_2.jpeg'], ['Kasım', 'GÜLER', 'ERCIS', '1970', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/394/FotoOrj.jpeg'], ['Bayram', 'NAMAZ', 'PATNOS', '1970', 'MLKP', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/93/FotoOrj.jpeg'], ['İbrahim', 'ŞENGÜL', 'ERMENEK', '1975', 'PKK/KCK', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/206/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/206/FotoOrj_2.jpeg'], ['İbrahim', 'ÇOBAN', 'ELBISTAN', '1974', 'PKK/KCK', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/97/FotoOrj.jpeg'], ['Hejar', 'ÇELIK', 'BATMAN', '1969', 'PKK/KCK', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/99/FotoOrj.jpeg'], ['Musa', 'ÇETINER', 'GÖZELEK', '1967', 'PKK/KCK', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/101/FotoOrj.jpeg'], ['Seyithan', 'SINET', 'BESIRI', '1974', 'PKK/
# ...

# %%
with open('response.json',"r+",encoding="'utf-8-sig") as f:
   
    data = (json.load(f,strict=False))
tamlist=list()
imglist=list()

tehlike=["kirmizi","mavi","yesil","turuncu","gri"]
for a in tehlike:
    for i in data[a]:
        
        
            #if(i['GorselURL']!="null" and i['Adi']!="Abdulgafur"):
                for c in i['GorselURL'] or []:
                    response = c
                    imglist.append(response)
           

                list1=[i['Adi'],i['Soyadi'],i['DogumYeri'],i['DogumTarihi'],i['TOrgutAdi'],i['TKategoriAdi']]
                list1=list1+imglist
                #print(list2)
                list1=map(str,list1)
                list1=list(list1)
            
                tamlist.append(list1)
                list2=[]
                imglist=[]
print(tamlist)
# Out:
# [['İlhami', 'BALI', 'TABUK', '1982', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_2.jpeg'], ['Mustafa', 'DOKUMACI', 'ADANA', '1985', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_2.jpeg'], ['Oguzhan', 'GÖZLEMECİOĞLU', 'ALTINDAG', '1980', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_2.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_3.jpeg'], ['Hasan', 'AYDIN', 'YÜREGIR', '1988', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_2.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_3.jpeg'], ['Deniz', 'BÜYÜKÇELEBİ', 'NIZIP', '1978', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/129/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/
# ...

# %%
tam=tamlist+tamliste
print(tam)
# Out:
# [['İlhami', 'BALI', 'TABUK', '1982', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_2.jpeg'], ['Mustafa', 'DOKUMACI', 'ADANA', '1985', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_2.jpeg'], ['Oguzhan', 'GÖZLEMECİOĞLU', 'ALTINDAG', '1980', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_2.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_3.jpeg'], ['Hasan', 'AYDIN', 'YÜREGIR', '1988', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_2.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/128/FotoOrj_3.jpeg'], ['Deniz', 'BÜYÜKÇELEBİ', 'NIZIP', '1978', 'DEAŞ', 'kırmızı', '/kurumlar/terorarananlar.pol.tr/Arsiv/129/FotoOrj_1.jpeg', '/kurumlar/terorarananlar.pol.tr/Arsiv/
# ...

# %%
t=["name","surname","birthplace","birthday","organizationname","categoryid","image1","image2","image3"]
data=[{k:v for k,v in zip(t,r)} for r in tam]
print(data)

# %%
df = pd.DataFrame(data, columns=["name","surname","birthplace","birthday","organizationname","categoryid","image1", "image2", "image3"])
df
df_1=df.fillna('null')
d_d=df_1.to_dict('records')
d_d
# Out:
# [{'name': 'İlhami',
#   'surname': 'BALI',
#   'birthplace': 'TABUK',
#   'birthday': '1982',
#   'organizationname': 'DEAŞ',
#   'categoryid': 'kırmızı',
#   'image1': '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_1.jpeg',
#   'image2': '/kurumlar/terorarananlar.pol.tr/Arsiv/22/FotoOrj_2.jpeg',
#   'image3': 'null'},
#  {'name': 'Mustafa',
#   'surname': 'DOKUMACI',
#   'birthplace': 'ADANA',
#   'birthday': '1985',
#   'organizationname': 'DEAŞ',
#   'categoryid': 'kırmızı',
#   'image1': '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_1.jpeg',
#   'image2': '/kurumlar/terorarananlar.pol.tr/Arsiv/28/FotoOrj_2.jpeg',
#   'image3': 'null'},
#  {'name': 'Oguzhan',
#   'surname': 'GÖZLEMECİOĞLU',
#   'birthplace': 'ALTINDAG',
#   'birthday': '1980',
#   'organizationname': 'DEAŞ',
#   'categoryid': 'kırmızı',
#   'image1': '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_1.jpeg',
#   'image2': '/kurumlar/terorarananlar.pol.tr/Arsiv/79/FotoOrj_2.jpeg',
# ...

# %%
engine = create_engine('postgresql+psycopg2://postgres:1111@localhost:5432/arananlar1_db',encoding='utf-8-sig', echo=True,executemany_mode='values_plus_batch',executemany_values_page_size=10000, executemany_batch_page_size=500 )
Session = sessionmaker(engine)
s = Session()

# %%
Base = declarative_base()

class Terrorists(Base):
    __tablename__ = 'terrorists'
    id = Column(Integer, primary_key=True)
    name = Column(TEXT)
    surname = Column(TEXT)
    birthplace = Column(TEXT)
    birthday= Column(TEXT)
    organizationname=Column(TEXT)
    categoryid=Column(String)
    
    
    
    def __repr__(self):
        return "<terrorists(name='{}', surname='{}', birthplace='{}', birthday='{}',organizationname='{}',categoryid='{}')>"\
                .format(self.name, self.surname, self.birthplace, self.birthday,self.organizationname,self.categoryid)

class Photo(Terrorists,Base):
    __tablename__ = 'photos'
    id = Column(Integer, primary_key=True)
    image1=Column(String)
    image2=Column(String)
    image3=Column(String)
    terrorists_id = Column(Integer, ForeignKey('terrorists.id'),primary_key=True)
    terrorists=relationship("Terrorists", back_populates="photos", lazy="raise") 

    def __repr__(self):
          return "<photos(image1='{}',image2='{}',image3='{}',terrorists_id='{}')>"\
                .format(self.image)      

    
Terrorists.photos=  relationship("Photo", order_by=Photo.id, back_populates="terrorists")               
Base.metadata.create_all(engine)
# Out:
# 2022-03-17 19:59:59,942 INFO sqlalchemy.engine.Engine select version()
# 2022-03-17 19:59:59,944 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-17 19:59:59,948 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-03-17 19:59:59,949 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-17 19:59:59,952 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-03-17 19:59:59,954 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-17 19:59:59,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-03-17 19:59:59,964 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-03-17 19:59:59,965 INFO sqlalchemy.engine.Engine [generated in 0.00176s] {'name': 'terrorists'}
# ...
